# %%
import json
import pandas as pd
import re

file_path = 'news.article.json'

# Load the JSON file
with open(file_path, 'rb') as file:
    articles = json.load(file)

# %%
# Convert to DataFrame
df = pd.DataFrame(articles)

# Display the structure of the DataFrame
df.head(7)
# Out:
#                                          articleBody  \
# 0  Sanjay Raut, a member of the Shiv Sena (UBT) p...
# 1  Kozhikode (Kerala) [India], October 27 (ANI): ...
# 2  Mumbai, Oct 24 (PTI) Maharashtra Chief Ministe...
# 3  Sensex, Nifty rebound over 1 pc after six sess...
# 4  October 26, 2023 08:15 pm | Updated 08:38 pm I...
# 5  Eight former officers of the Indian Navy have ...
# 6  October 26, 2023 07:21 pm | Updated October 27...
#
#                             dateModified  \
# 0  {'$date': '2023-10-25T06:35:50.000Z'}
# 1                                    NaN
# 2  {'$date': '2023-10-25T02:14:27.000Z'}
# 3                                    NaN
# 4  {'$date': '2023-10-26T14:45:24.000Z'}
# 5  {'$date': '2023-10-26T11:22:00.000Z'}
# 6  {'$date': '2023-10-26T13:51:52.000Z'}
#
#                              scrapedDate                             source  \
# 0  {'$date': '2023-10-27T13:12:18.339Z'}      https://www.thehansindia.com/
# 1  {'$date': '2023-10-27T13:12:45.595Z'}            https://www.aninews.in/
# 2  {'$date': '2023-10-27T13:12:18.339Z'}            https://thefederal.com/
# 3  {'$date': '2023-10-27T13:12:41.618Z'}  https://english.varthabharati.in/
# 4  {'$date': '2023-10-27T13:12:45.595Z'}          https://www.thehindu.com/
# 5  {'$date': '2023-10-27T13:12:47.852Z'}        https://english.jagran.com/
# 6  {'$date': '2023-10-27T13:12:45.595Z'}          https://www.thehindu.com/
#
#                                                title
# 0  Shiv Sena MP Sanjay Raut Responds To 'Hamas' R...
# 1  At IUML's pro-Palestine rally in Kerala Tharoo...
# 2  Uddhav buried Bal Thackeray's 'Hindutva' for p...
# 3  New Bills replacing IPC, CrPC, Evidence Act wi...
# 4  Israel biggest terrorist nation in the world, ...
# 5  Eight Ex-Indian Navy Officers Get Death Penalt...
# 6  Israel’s response to Hamas terrorist attack di...

# %%
df = df.drop(['dateModified', 'source'], axis=1)
df.shape
# Out:
# (37421, 3)

# %%
df.isna().sum()
# Out:
# articleBody    0
# scrapedDate    0
# title          0
# dtype: int64

# %%
import nltk
import re

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BASHA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.head(2)
# Out:
#                                          articleBody  \
# 0  Sanjay Raut, a member of the Shiv Sena (UBT) p...
# 1  Kozhikode (Kerala) [India], October 27 (ANI): ...
#
#                              scrapedDate  \
# 0  {'$date': '2023-10-27T13:12:18.339Z'}
# 1  {'$date': '2023-10-27T13:12:45.595Z'}
#
#                                                title
# 0  Shiv Sena MP Sanjay Raut Responds To 'Hamas' R...
# 1  At IUML's pro-Palestine rally in Kerala Tharoo...

# %%
def clean_text(text):
    # Remove punctuation and special characters
    cleaned_text = re.sub(r'[^\w\s]', '', text)
    # Remove extra spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    return cleaned_text.strip()
    
df['articleBody'] = df['articleBody'].apply(clean_text)
df['title'] = df['title'].apply(clean_text)

# %%
df.head(2)
# Out:
#                                          articleBody  \
# 0  Sanjay Raut a member of the Shiv Sena UBT part...
# 1  Kozhikode Kerala India October 27 ANI Pointing...
#
#                              scrapedDate  \
# 0  {'$date': '2023-10-27T13:12:18.339Z'}
# 1  {'$date': '2023-10-27T13:12:45.595Z'}
#
#                                                title
# 0  Shiv Sena MP Sanjay Raut Responds To Hamas Rem...
# 1  At IUMLs proPalestine rally in Kerala Tharoor ...

# %%
def extract_date(date_dict):
    return pd.to_datetime(date_dict['$date'])

# Apply the function to the 'scrapedDate' column
df['scrapedDate'] = df['scrapedDate'].apply(extract_date)

# %%
df.head(3)
# Out:
#                                          articleBody  \
# 0  Sanjay Raut a member of the Shiv Sena UBT part...
# 1  Kozhikode Kerala India October 27 ANI Pointing...
# 2  Mumbai Oct 24 PTI Maharashtra Chief Minister E...
#
#                        scrapedDate  \
# 0 2023-10-27 13:12:18.339000+00:00
# 1 2023-10-27 13:12:45.595000+00:00
# 2 2023-10-27 13:12:18.339000+00:00
#
#                                                title
# 0  Shiv Sena MP Sanjay Raut Responds To Hamas Rem...
# 1  At IUMLs proPalestine rally in Kerala Tharoor ...
# 2  Uddhav buried Bal Thackerays Hindutva for powe...

# %%
new_column_names = {'scrapedDate': 'date', 'articleBody': 'desc'} 
df = df.rename(columns=new_column_names)

df.head()
# Out:
#                                                 desc  \
# 0  Sanjay Raut a member of the Shiv Sena UBT part...
# 1  Kozhikode Kerala India October 27 ANI Pointing...
# 2  Mumbai Oct 24 PTI Maharashtra Chief Minister E...
# 3  Sensex Nifty rebound over 1 pc after six sessi...
# 4  October 26 2023 0815 pm Updated 0838 pm IST Ko...
#
#                               date  \
# 0 2023-10-27 13:12:18.339000+00:00
# 1 2023-10-27 13:12:45.595000+00:00
# 2 2023-10-27 13:12:18.339000+00:00
# 3 2023-10-27 13:12:41.618000+00:00
# 4 2023-10-27 13:12:45.595000+00:00
#
#                                                title
# 0  Shiv Sena MP Sanjay Raut Responds To Hamas Rem...
# 1  At IUMLs proPalestine rally in Kerala Tharoor ...
# 2  Uddhav buried Bal Thackerays Hindutva for powe...
# 3  New Bills replacing IPC CrPC Evidence Act will...
# 4  Israel biggest terrorist nation in the world s...

# %%
df
# Out:
#                                                     desc  \
# 0      Sanjay Raut a member of the Shiv Sena UBT part...
# 1      Kozhikode Kerala India October 27 ANI Pointing...
# 2      Mumbai Oct 24 PTI Maharashtra Chief Minister E...
# 3      Sensex Nifty rebound over 1 pc after six sessi...
# 4      October 26 2023 0815 pm Updated 0838 pm IST Ko...
# ...                                                  ...
# 37416  Lebanese media are reporting renewed IDF strik...
# 37417  Amid escalating tensions and concerns over pot...
# 37418  Haaretzcom the online English edition of Haare...
# 37419  The UN secretary general António Guterres has ...
# 37420  Aam Aadmi Party AAP leader Raghav Chadha recen...
#
#                                   date  \
# 0     2023-10-27 13:12:18.339000+00:00
# 1     2023-10-27 13:12:45.595000+00:00
# 2     2023-10-27 13:12:18.339000+00:00
# 3     2023-10-27 13:12:41.618000+00:00
# 4     2023-10-27 13:12:45.595000+00:00
# ...                                ...
# 37416 2024-03-31 03:10:17.646000+00:00
# 37417 2024-03-31 03:09:38.331000+00:00
# 37418 2024-03-31 03:09:46.683000+00:00
# 37419 2024-03-31 03:09:50.586000+00:00
# 37420 2024-03-31 03:13:43.646000+00:00
#
#                                                    title
# 0      Shiv Sena MP Sanjay Raut Responds To Hamas Rem...
# 1      At IUMLs proPalestine rally in Kerala Tharoor ...
# 2      Uddhav buried Bal Thackerays Hindutva for powe...
# 3      New Bills replacing IPC CrPC Evidence Act will...
# 4      Israel biggest terrorist nation in the world s...
# ...                                                  ...
# 37416  Lebanese media reports renewed IDF strikes in ...
# 37417  US approves additional bombs warplanes sales t...
# 37418  Israel Publishes Video of Islamic Jihad Terror...
# 37419  United Nations secretary general condemns expl...
# 37420  Raghav Chadha stirs a row as he meets this UK ...
#
# [37421 rows x 3 columns]

# %%
import pickle

# %%
with open('articles.pickle', 'wb') as file:
    pickle.dump(df, file)
